# %%
# %run bib
import pandas as pd 
csvFile = "./resources/vermoegensbilanzen-xlsx-5816103.csv"


data = pd.read_csv(csvFile, sep=",")
data = data.fillna("")
# Preview the first 5 lines of the loaded data 
data.head()
# Out:
#   Aktive/Passive        Subcategory 1  Subcategory 2  \
# 0         Aktiva
# 1         Aktiva         Sachvermögen
# 2         Aktiva  Alle Anlagegüter 1)
# 3         Aktiva  Alle Anlagegüter 1)  Sachanlagen
# 4         Aktiva  Alle Anlagegüter 1)  Sachanlagen
#
#                      Subcategory 3 Subcategory 4  Year   Amount
# 0                                                 1999  11734.0
# 1                                                 1999   8977.1
# 2                                                 1999   6609.4
# 3                                                 1999   6335.8
# 4  Nutztiere und Nutzpflanzungen                  1999      7.0

# %%
# data.filter(items=['Year', 'Amount'])
# data.groupby(['Year']).sum()

a = data['Amount'] < 10
data[a]
# data
# data.sum(axis = 1, skipna = True)
# Out:
#     Aktive/Passive        Subcategory 1  Subcategory 2  \
# 4           Aktiva  Alle Anlagegüter 1)  Sachanlagen
# 17          Aktiva  Alle Anlagegüter 1)  Sachanlagen
# 30          Aktiva  Alle Anlagegüter 1)  Sachanlagen
# 43          Aktiva  Alle Anlagegüter 1)  Sachanlagen
# 56          Aktiva  Alle Anlagegüter 1)  Sachanlagen
# 69          Aktiva  Alle Anlagegüter 1)  Sachanlagen
# 82          Aktiva  Alle Anlagegüter 1)  Sachanlagen
# 95          Aktiva  Alle Anlagegüter 1)  Sachanlagen
# 108         Aktiva  Alle Anlagegüter 1)  Sachanlagen
# 121         Aktiva  Alle Anlagegüter 1)  Sachanlagen
# 134         Aktiva  Alle Anlagegüter 1)  Sachanlagen
# 147         Aktiva  Alle Anlagegüter 1)  Sachanlagen
# 160         Aktiva  Alle Anlagegüter 1)  Sachanlagen
# 199         Aktiva  Alle Anlagegüter 1)  Sachanlagen
# 225         Aktiva  Alle Anlagegüter 1)  Sachanlagen
# 238         Aktiva  Alle Anlagegüter 1)  Sachanlagen
#
# ...
